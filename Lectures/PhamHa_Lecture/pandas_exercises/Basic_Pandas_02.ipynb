# %% [markdown]
# # Basic Pandas practice

# %%
import numpy as np
import pandas as pd

# %%
chipo_df=pd.read_csv('https://raw.githubusercontent.com/datacuriosity/MCI_Python_28S_Level_1/main/Lectures/PhamHa_Lecture/chipotle.tsv', delimiter='\t')
chipo_df.head
# Out:
# <bound method NDFrame.head of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
type(chipo_df)
# Out:
# pandas.core.frame.DataFrame

# %%
chipo_df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo_df[5:10]
# Out:
#    order_id  quantity         item_name  \
# 5         3         1      Chicken Bowl
# 6         3         1     Side of Chips
# 7         4         1     Steak Burrito
# 8         4         1  Steak Soft Tacos
# 9         5         1     Steak Burrito
#
#                                   choice_description item_price
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
chipo_df[5:]
# Out:
#       order_id  quantity           item_name  \
# 5            3         1        Chicken Bowl
# 6            3         1       Side of Chips
# 7            4         1       Steak Burrito
# 8            4         1    Steak Soft Tacos
# 9            5         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                   NaN     $1.69
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# ...

# %%
chipo_df[:5]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo_df.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# ### Các chức năng của .loc:
# - Lấy 1 số cột
# - Lấy 1 số dòng và 1 số cột

# %%
chipo_df.loc[50:55] #Chọn các hàng từ 50 đến 55
# Out:
#     order_id  quantity                     item_name  \
# 50        23         1                 Steak Burrito
# 51        23         2                   Canned Soda
# 52        24         1               Chicken Burrito
# 53        24         1                   Canned Soda
# 54        25         1                    Steak Bowl
# 55        25         1  Chips and Fresh Tomato Salsa
#
#                                    choice_description item_price
# 50  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...     $8.99
# 51                                     [Mountain Dew]     $2.18
# 52  [Roasted Chili Corn Salsa (Medium), [Black Bea...    $10.98
# 53                                           [Sprite]     $1.09
# 54  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.99
# 55                                                NaN     $2.39

# %%
chipo_df.loc[50:55,'item_name':'item_price'] #Chọn các hàng từ 50 đến 55, từ cột 'item_name' đến cột 'item_price'. .loc có sẵn
# Out:
#                        item_name  \
# 50                 Steak Burrito
# 51                   Canned Soda
# 52               Chicken Burrito
# 53                   Canned Soda
# 54                    Steak Bowl
# 55  Chips and Fresh Tomato Salsa
#
#                                    choice_description item_price
# 50  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...     $8.99
# 51                                     [Mountain Dew]     $2.18
# 52  [Roasted Chili Corn Salsa (Medium), [Black Bea...    $10.98
# 53                                           [Sprite]     $1.09
# 54  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.99
# 55                                                NaN     $2.39
