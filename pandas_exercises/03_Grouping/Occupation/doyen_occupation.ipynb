# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
oc=pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',delimiter='|')
oc
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
oc.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
oc_1=oc.groupby(['occupation']).gender.agg(['count'])
oc_2=oc.groupby(['occupation','gender']).gender.agg(['count']).query("gender=='M'")

# %%
oc_4=oc_2.div(oc_1, level='occupation')
oc_4.sort_values(by='count')
# Out:
#                          count
# occupation    gender
# homemaker     M       0.142857
# healthcare    M       0.312500
# librarian     M       0.431373
# artist        M       0.535714
# administrator M       0.544304
# none          M       0.555556
# writer        M       0.577778
# marketing     M       0.615385
# other         M       0.657143
# student       M       0.693878
# educator      M       0.726316
# salesman      M       0.750000
# lawyer        M       0.833333
# entertainment M       0.888889
# scientist     M       0.903226
# executive     M       0.906250
# programmer    M       0.909091
# retired       M       0.928571
# technician    M       0.962963
# engineer      M       0.970149
# doctor        M       1.000000

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
oc.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
oc.groupby(['occupation','gender']).age.agg(['min','max'])
# Out:
#                       min  max
# occupation    gender
# administrator F        22   62
#               M        21   70
# artist        F        19   48
#               M        20   45
# doctor        M        28   64
# educator      F        23   51
#               M        25   63
# engineer      F        23   36
#               M        22   70
# entertainment F        24   38
#               M        15   50
# executive     F        39   49
#               M        22   69
# healthcare    F        22   53
#               M        28   62
# homemaker     F        20   50
#               M        23   23
# lawyer        F        28   51
#               M        21   53
# librarian     F        26   59
#               M        23   69
# marketing     F        24   50
#               M        24   55
# none          F        26   55
#               M        11   33
# other         F        18   55
#               M        13   64
# programmer    F        26   38
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
oc_1=oc.groupby(['occupation']).gender.agg(['count'])
oc_5=oc.groupby(['occupation','gender']).gender.agg(['count'])

# %%
oc_3=oc_5.div(oc_1, level='occupation')*100
oc_3
# Out:
#                            count
# occupation    gender
# administrator F        45.569620
#               M        54.430380
# artist        F        46.428571
#               M        53.571429
# doctor        M       100.000000
# educator      F        27.368421
#               M        72.631579
# engineer      F         2.985075
#               M        97.014925
# entertainment F        11.111111
#               M        88.888889
# executive     F         9.375000
#               M        90.625000
# healthcare    F        68.750000
#               M        31.250000
# homemaker     F        85.714286
#               M        14.285714
# lawyer        F        16.666667
#               M        83.333333
# librarian     F        56.862745
#               M        43.137255
# marketing     F        38.461538
#               M        61.538462
# none          F        44.444444
#               M        55.555556
# other         F        34.285714
# ...
